# %% [markdown]
# # **Trabalhando com Planilhas do Excel**

# %% [markdown]
# ## **Introdução**

# %%
# Importando a biblioteca
import pandas as pd

# %%
# Leitura dos arquivos temporários
# df1 = pd.read_excel("Aracaju.xlsx")
# df2 = pd.read_excel("Fortaleza.xlsx")
# df3 = pd.read_excel("Natal.xlsx")
# df4 = pd.read_excel("Recife.xlsx")
# df5 = pd.read_excel("Salvador.xlsx"

# %%
df1 = pd.read_excel("/content/drive/MyDrive/Desafio de Projeto Python/Datasets/Aracaju.xlsx")
df2 = pd.read_excel("/content/drive/MyDrive/Desafio de Projeto Python/Datasets/Fortaleza.xlsx")
df3 = pd.read_excel("/content/drive/MyDrive/Desafio de Projeto Python/Datasets/Natal.xlsx")
df4 = pd.read_excel("/content/drive/MyDrive/Desafio de Projeto Python/Datasets/Recife.xlsx")
df5 = pd.read_excel("/content/drive/MyDrive/Desafio de Projeto Python/Datasets/Salvador.xlsx")

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %%
# Juntando todos os arquivos
df = pd.concat([df1, df2, df3, df4, df5])

# %%
# Exibindo as 5 primeiras linhas
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
# Exibindo as 5 últimas linhas
df.tail()
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde
# 235  Salvador 2019-01-03   41.84    1034     1
# 236  Salvador 2019-01-03  126.29    1035     3
# 237  Salvador 2019-01-03   38.06    1036     3
# 238  Salvador 2019-01-03  139.64    1035     1
# 239  Salvador 2019-01-03  161.41    1037     3

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde
# 93   Fortaleza 2019-01-01   35.25    1003     5
# 132      Natal 2019-01-02   19.61    1036     2
# 182      Natal 2019-01-02    6.60    1037     2
# 211      Natal 2019-01-02  141.05    1035     3
# 73       Natal 2018-01-05  773.00     852     2

# %%
# Verificando o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Alterando o tipode dado da coluna LojaID
df["LojaID"] = df["LojaID"].astype("object")

# %%
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID            object
# Qtde               int64
# dtype: object

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00   1520     1
# 1  Aracaju 2018-01-01   14.21   1522     6
# 2  Aracaju 2018-01-01   71.55   1520     1
# 3  Aracaju 2018-01-01    3.01   1521     7
# 4  Aracaju 2018-01-01   24.51   1522     8

# %% [markdown]
# ## **Tratando valores faltantes**

# %%
# Consultando linhas com valores faltantes
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
# Substituindo os valores nulos pela média
df["Vendas"].fillna(df["Vendas"].mean(), inplace=True)

# %%
df["Vendas"].mean()
# Out:
# 122.61180089485458

# %%
df.isnull().sum()
# Out:
# Cidade    0
# Data      0
# Vendas    0
# LojaID    0
# Qtde      0
# dtype: int64

# %%
df.sample(15)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde
# 222      Natal 2019-01-02   43.96   1037     1
# 61   Fortaleza 2019-01-01   37.41   1002     5
# 57   Fortaleza 2019-01-01  129.07   1005     3
# 168   Salvador 2019-01-02   20.22   1036     1
# 74   Fortaleza 2019-01-01  163.09   1005     5
# 238   Salvador 2019-01-03  139.64   1035     1
# 113  Fortaleza 2019-03-02   38.63    980     2
# 74     Aracaju 2018-01-01    7.86   1520     2
# 3    Fortaleza 2019-02-10   20.95   1004     6
# 136   Salvador 2019-03-02   13.81   1036     1
# 233      Natal 2019-01-03  172.40   1036     2
# 110      Natal 2019-01-02  185.93   1036     3
# 137   Salvador 2019-03-02   51.66   1036     3
# 68       Natal 2018-06-22  274.00    852     3
# 126      Natal 2019-01-02   41.69   1036     2

# %%
# Substituindo os valores nulos por zero
df["Vendas"].fillna(0, inplace=True)

# %%
# Apagando as linhas com valores nulos
df.dropna(inplace=True)

# %%
# Apagando as linhas com valores nulos com base apenas em 1 coluna
df.dropna(subset=["Vendas"], inplace=True)

# %%
# Removendo linhas que estejam com valores faltantes em todas as colunas
df.dropna(how="all", inplace=True)

# %% [markdown]
# ## **Criando colunas novas**

# %%
# Criando a coluna de receita
df["Receita"] = df["Vendas"].mul(df["Qtde"])

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08

# %%
df["Receita/Vendas"] = df["Receita"] / df["Vendas"]

# %%
df.head()
# Out:
#     Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 0  Aracaju 2018-01-01  142.00   1520     1   142.00             1.0
# 1  Aracaju 2018-01-01   14.21   1522     6    85.26             6.0
# 2  Aracaju 2018-01-01   71.55   1520     1    71.55             1.0
# 3  Aracaju 2018-01-01    3.01   1521     7    21.07             7.0
# 4  Aracaju 2018-01-01   24.51   1522     8   196.08             8.0

# %%
# Retornando a maior receita
df["Receita"].max()
# Out:
# 3544.0

# %%
# Retornando a menor receita
df["Receita"].min()
# Out:
# 3.34

# %%
# nlargest
df.nlargest(3, "Receita")
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0

# %%
# nsmallest
df.nsmallest(3, "Receita")
# Out:
#       Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 118  Aracaju 2018-01-01    3.34   1522     1     3.34             1.0
# 65    Recife 2019-01-01    4.01    981     1     4.01             1.0
# 92     Natal 2019-01-02    4.57   1035     1     4.57             1.0

# %%
# Agrupamento por cidade
df.groupby("Cidade")["Receita"].sum()
# Out:
# Cidade
# Aracaju       48748.25
# Fortaleza     37913.97
# Natal        167227.52
# Recife        51936.51
# Salvador      40596.73
# Name: Receita, dtype: float64

# %%
# Ordenando o conjunto de dados
df.sort_values("Receita", ascending=False).head(10)
# Out:
#    Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas
# 7   Natal 2019-03-18   886.0    853     4   3544.0             4.0
# 55  Natal 2019-01-08   859.0    854     4   3436.0             4.0
# 51  Natal 2018-01-21   859.0    852     4   3436.0             4.0
# 30  Natal 2018-10-02   856.0    853     4   3424.0             4.0
# 41  Natal 2018-05-20   835.0    852     4   3340.0             4.0
# 38  Natal 2018-02-25   828.0    852     4   3312.0             4.0
# 10  Natal 2018-10-27   828.0    852     4   3312.0             4.0
# 69  Natal 2019-03-24   817.0    852     4   3268.0             4.0
# 62  Natal 2018-02-10   793.0    854     4   3172.0             4.0
# 52  Natal 2018-04-27   778.0    854     4   3112.0             4.0

# %% [markdown]
# ## **Trabalhando com datas**

# %%
# Transformando a coluna de data em tipo inteiro
df["Data"] = df["Data"].astype("int64")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
# Verificando a coluna de data em tipo inteiro
df.dtypes
# Out:
# Cidade             object
# Data                int64
# Vendas            float64
# LojaID             object
# Qtde                int64
# Receita           float64
# Receita/Vendas    float64
# dtype: object

# %%
# Transformando coluna de data em data
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Cidade                    object
# Data              datetime64[ns]
# Vendas                   float64
# LojaID                    object
# Qtde                       int64
# Receita                  float64
# Receita/Vendas           float64
# dtype: object

# %%
# Agrupamento por ano
df.groupby(df["Data"].dt.year)["Receita"].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criando uma nova coluna com o ano
df["Ano_Venda"] = df["Data"].dt.year

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 52   Fortaleza 2019-01-01   15.22   1003     2    30.44             2.0
# 126    Aracaju 2018-01-01   13.41   1520     7    93.87             7.0
# 13     Aracaju 2018-01-01   43.45   1522    10   434.50            10.0
# 34     Aracaju 2018-01-01   38.25   1521     6   229.50             6.0
# 57      Recife 2019-01-01  201.41    980     3   604.23             3.0
#
#      Ano_Venda
# 52        2019
# 126       2018
# 13        2018
# 34        2018
# 57        2019

# %%
# Extraindo o mês e o dia
df["mes_venda"], df["dia_venda"] = (df["Data"].dt.month, df["Data"].dt.day)

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 44   Fortaleza 2019-01-01  215.11   1003     1   215.11             1.0
# 56   Fortaleza 2019-01-01   18.43   1002     1    18.43             1.0
# 35     Aracaju 2018-01-01   40.60   1520     3   121.80             3.0
# 201      Natal 2019-01-02   86.61   1036     1    86.61             1.0
# 33      Recife 2019-01-01   32.33    982     1    32.33             1.0
#
#      Ano_Venda  mes_venda  dia_venda
# 44        2019          1          1
# 56        2019          1          1
# 35        2018          1          1
# 201       2019          1          2
# 33        2019          1          1

# %%
# Retornando a data mais antiga
df["Data"].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calculando a difereça de dias
df["diferenca_dias"] = df["Data"] - df["Data"].min()

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 99       Natal 2019-01-02   40.38   1037     1    40.38             1.0
# 166   Salvador 2019-01-02  111.72   1035     3   335.16             3.0
# 20     Aracaju 2018-01-01   39.86   1522     9   358.74             9.0
# 18   Fortaleza 2019-01-01   38.31   1002     3   114.93             3.0
# 7      Aracaju 2019-01-01  172.22   1522     6  1033.32             6.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias
# 99        2019          1          2       366 days
# 166       2019          1          2       366 days
# 20        2018          1          1         0 days
# 18        2019          1          1       365 days
# 7         2019          1          1       365 days

# %%
# Criando a coluna de trimestre
df["trimestre_venda"] = df["Data"].dt.quarter

# %%
df.sample(5)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 1    Fortaleza 2019-01-01  115.61   1002     3   346.83             3.0
# 22      Recife 2019-01-01   39.53    983     3   118.59             3.0
# 135     Recife 2019-03-02   10.79    983     5    53.95             5.0
# 73     Aracaju 2018-01-01  159.78   1521     3   479.34             3.0
# 47       Natal 2018-03-13  521.00    854     3  1563.00             3.0
#
#      Ano_Venda  mes_venda  dia_venda diferenca_dias  trimestre_venda
# 1         2019          1          1       365 days                1
# 22        2019          1          1       365 days                1
# 135       2019          3          2       425 days                1
# 73        2018          1          1         0 days                1
# 47        2018          3         13        71 days                1

# %%
#  Filtrando as vendas de 2019 do mês de março
vendas_marco_19 = df.loc[(df["Data"].dt.year == 2019) & (df["Data"].dt.month == 3)]

# %%
vendas_marco_19.sample(20)
# Out:
#         Cidade       Data  Vendas LojaID  Qtde  Receita  Receita/Vendas  \
# 108   Salvador 2019-03-02   11.72   1037     1    11.72             1.0
# 126   Salvador 2019-03-02   41.69   1036     2    83.38             2.0
# 18       Natal 2019-03-14  581.00    853     3  1743.00             3.0
# 125     Recife 2019-03-02   37.60    983     4   150.40             4.0
# 135     Recife 2019-03-02   10.79    983     5    53.95             5.0
# 130   Salvador 2019-03-02   59.78   1036     1    59.78             1.0
# 114  Fortaleza 2019-03-02   16.82    983     4    67.28             4.0
# 132  Fortaleza 2019-03-02   17.49    983     5    87.45             5.0
# 69       Natal 2019-03-24  817.00    852     4  3268.00             4.0
# 136   Salvador 2019-03-02   13.81   1036     1    13.81             1.0
# 113     Recife 2019-03-02   38.63    980     2    77.26             2.0
# 136  Fortaleza 2019-03-02   39.09    982     4   156.36             4.0
# ...

# %% [markdown]
# ## **Visualização de dados**

# %%
# Value counts faz uma contagem e o ascending apresenta do maior para o menor
df["LojaID"].value_counts(ascending=False)
# Out:
# 1036    117
# 1035    112
# 1037    101
# 1034     67
# 983      65
# 982      44
# 1522     41
# 1520     39
# 980      36
# 981      31
# 1005     30
# 1002     30
# 852      29
# 1523     29
# 1004     28
# 854      28
# 853      26
# 1521     21
# 1003     20
# Name: LojaID, dtype: int64

# %%
# Gráfico de barras com linhas verticais
df["LojaID"].value_counts(ascending=False).plot.bar()

# %%
# Gráfico de barras horizontais
df["LojaID"].value_counts(ascending=False).plot.barh()

# %%
# Gráfico de barras horizontais do maior para o menor # O ; é utilizado para não exibir a mensagem acima do gráfico
df["LojaID"].value_counts(ascending=True).plot.barh();

# %%
# Gráfico de Pizza
df.groupby(df["Data"].dt.year)["Receita"].sum().plot.pie()

# %%
# Total de vendas por cidade
df["Cidade"].value_counts()
# Out:
# Natal        240
# Salvador     240
# Fortaleza    142
# Recife       142
# Aracaju      130
# Name: Cidade, dtype: int64

# %%
# Adicionando um título e alterando o nome dos eixos
import matplotlib.pyplot as plt
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
# Alterando a cor
df["Cidade"].value_counts().plot.bar(title="Total vendas por Cidade", color="red")
plt.xlabel("Cidade")
plt.ylabel("Total Vendas");

# %%
# Alterando o estilo
plt.style.use("seaborn-pastel")

# %%
df.groupby(df["mes_venda"])["Qtde"].sum().plot(title = "Total Produtos Vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend()

# %%
df.groupby(df["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1     2208
# 2      144
# 3      467
# 4       23
# 5       17
# 6       13
# 7       13
# 8        2
# 9       10
# 10      14
# 11       2
# 12       3
# Name: Qtde, dtype: int64

# %%
# Selecionando apenas as vendas de 2019
df_2019 = df[df["Ano_Venda"] == 2019]

# %%
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum()
# Out:
# mes_venda
# 1    1541
# 2     128
# 3     460
# 4      12
# Name: Qtde, dtype: int64

# %%
# Total produtos Vendidos por mês
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "o")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos")
plt.legend();

# %%
# Hisograma
plt.hist(df["Qtde"], color="pink");

# %%
plt.scatter(x=df_2019["dia_venda"], y = df_2019["Receita"])

# %%
# Salvando em PNG
df_2019.groupby(df_2019["mes_venda"])["Qtde"].sum().plot(marker = "v")
plt.title("Quantidade de produtos vendidos x Mês")
plt.xlabel("Mês")
plt.ylabel("Total Produtos Vendidos");
plt.legend()
plt.savefig("grafico QTDE X MES.png")
